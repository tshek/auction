# %% [markdown]
# <a href="https://colab.research.google.com/github/johnkershaw/auction/blob/master/germaine/Auction_Germaine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DONE: Store items
#DONE: Create display
#DONE: Ask and display item, item number, description and the current highest bid. 
#DONE: Enter buyer number
#DONE: Enter bid
#DONE: Add bid to the number of bids for that item
#DONE: Make a loop
#DONE: Deal with bids, highest bid, and reserve complications
#DONE: Total fee
#DONE: Reserve not met
#DONE: Unbid items
#DONE: Add highest bid to items with unmet reserve
#TODO: Deal with possible human errors


buyers = []

print("Welcome to auctions.com! Here are our items today: ")

items = {
  1 : {"item_num: " :  1, "description: " : "shelf", "bid_num: " : 0, "reserve: " : 75.00, "highest_bid: ": 0,},
  2 : {"item_num: " :  2, "description: " : "table", "bid_num: " : 0, "reserve: " : 39.00, "highest_bid: ": 0,},
  3 : {"item_num: " :  3, "description: " : "lamp","bid_num: " : 0, "reserve: " : 40.00, "highest_bid: ": 0,},
  4 : {"item_num: " :  4, "description: " : "dishes(4)", "bid_num: " : 0, "reserve: " : 25.00, "highest_bid: ": 0,},
  5 : {"item_num: " :  5, "description: " : "pram", "bid_num: " : 0, "reserve: " : 25.00, "highest_bid: ": 0,}, 
  6 : {"item_num: " :  6, "description: " : "tea set", "bid_num: " : 0, "reserve: " : 26.00, "highest_bid: ": 0,}, 
  7 : {"item_num: " :  7, "description: " : "ink set", "bid_num: " : 0, "reserve: " : 30.00, "highest_bid: ": 0,},  
  8 : {"item_num: " :  8, "description: " : "writing desk", "bid_num: " : 0, "reserve: " : 50.00, "highest_bid: ": 0,},
  9 : {"item_num: " :  9, "description: " : "glass case", "bid_num: " : 0, "reserve: " : 150.00, "highest_bid: ": 0,},  
 10 : {"item_num: " : 10, "description: " : "stone phoenix", "bid_num: " : 0, "reserve: " : 250.00, "highest_bid: ": 0,},  
}

def screen():
  print ("item number" + "     " + "description" + "     " + "number of bids" + "     " + "reserve price($)")

  print("    " + str(items[1]["item_num: "]) + "             " + items[1]["description: "] + "                " + str(items[1]["bid_num: "]) + "                " + str(items[1]["reserve: "]))
  print("    " + str(items[2]["item_num: "]) + "             " + items[2]["description: "] + "                " + str(items[2]["bid_num: "]) + "                " + str(items[2]["reserve: "]))
  print("    " + str(items[3]["item_num: "]) + "              " + items[3]["description: "] + "                " + str(items[3]["bid_num: "]) + "                " + str(items[3]["reserve: "]))
  print("    " + str(items[4]["item_num: "]) + "         " + items[4]["description: "] + "                " + str(items[4]["bid_num: "]) + "                " + str(items[4]["reserve: "]))
  print("    " + str(items[5]["item_num: "]) + "              " + items[5]["description: "] + "                " + str(items[5]["bid_num: "]) + "                " + str(items[5]["reserve: "]))
  print("    " + str(items[6]["item_num: "]) + "           " + items[6]["description: "] + "                " + str(items[6]["bid_num: "]) + "                " + str(items[6]["reserve: "]))
  print("    " + str(items[7]["item_num: "]) + "           " + items[7]["description: "] + "                " + str(items[7]["bid_num: "]) + "                " + str(items[7]["reserve: "]))
  print("    " + str(items[8]["item_num: "]) + "      " + items[8]["description: "] + "                " + str(items[8]["bid_num: "]) + "                " + str(items[8]["reserve: "]))
  print("    " + str(items[9]["item_num: "]) + "        " + items[9]["description: "] + "                " + str(items[9]["bid_num: "]) + "                " + str(items[9]["reserve: "]))
  print("    " + str(items[10]["item_num: "]) + "    " + items[10]["description: "] + "                " + str(items[10]["bid_num: "]) + "                " + str(items[10]["reserve: "]))

screen()

quit = False

buyer_num = input("Enter user id: ")
buyers.append(buyer_num)

while not quit:
  screen()
  bid = input("Enter the item number of the item you want to bid for. Type 'q' to stop: ")
  if bid != 'q':
    print(items[int(bid)])
    items[int(bid)]["bid_num: "] += 1
    cash = input("Enter bid (without $ sign): ")
    if float(cash) >= items[int(bid)]["highest_bid: "]:
      items[int(bid)]["highest_bid: "] = float(cash)
      if items[int(bid)]["highest_bid: "] >= items[int(bid)]["reserve: "]:
        print("Okay, reserve met.")
        #print(items[int(bid)]["highest_bid: "])
      else:
        print("Okay, reserve not met.")
  else:
    quit = True
    print("Thank you for shopping with us on auctions.com.")

#print(buyers)
#Bid again? (y/n) n

print("Company info:")

def calc_fee():
  profit = 0
  sold = 0
  if items[1]["highest_bid: "] > items[1]["reserve: "]:
    profit += (items[1]["highest_bid: "] * 1.1)
    sold += 1
  if items[2]["highest_bid: "] > items[2]["reserve: "]:
    profit += (items[2]["highest_bid: "] * 1.1)
    sold += 1
  if items[3]["highest_bid: "] > items[3]["reserve: "]:
    profit += (items[3]["highest_bid: "] * 1.1)
    sold += 1
  if items[4]["highest_bid: "] > items[4]["reserve: "]: 
    profit += (items[4]["highest_bid: "] * 1.1)
    sold += 1
  if items[5]["highest_bid: "] > items[5]["reserve: "]:
    profit += (items[5]["highest_bid: "] * 1.1)
    sold += 1
  if items[6]["highest_bid: "] > items[6]["reserve: "]:
    profit += (items[6]["highest_bid: "] * 1.1)
    sold += 1
  if items[7]["highest_bid: "] > items[7]["reserve: "]:
    profit += (items[7]["highest_bid: "] * 1.1)
    sold += 1
  if items[8]["highest_bid: "] > items[8]["reserve: "]:
    profit += (items[8]["highest_bid: "] * 1.1)
    sold += 1
  if items[9]["highest_bid: "] > items[9]["reserve: "]:
    profit += (items[9]["highest_bid: "] * 1.1)
    sold += 1
  if items[10]["highest_bid: "] > items[10]["reserve: "]:
    profit += (items[10]["highest_bid: "] * 1.1)
    sold += 1
  
  return sold,profit
  
def total_fee():
  sold, profit = calc_fee()
  print("Total fee: " + str(round(profit, 2)))
  print("No. of items sold: " + str(sold))

def reserve_unmet():
  unmet = []
  if items[1]["highest_bid: "] < items[1]["reserve: "] and items[1]["bid_num: "] > 0:
    unmet.append(str(items[1]["item_num: "]))
  if items[2]["highest_bid: "] < items[2]["reserve: "]and items[2]["bid_num: "] > 0:
    unmet.append(str(items[2]["item_num: "]))
  if items[3]["highest_bid: "] < items[3]["reserve: "]and items[3]["bid_num: "] > 0:
    unmet.append(str(items[3]["item_num: "]))
  if items[4]["highest_bid: "] < items[4]["reserve: "]and items[4]["bid_num: "] > 0: 
    unmet.append(str(items[4]["item_num: "]))
  if items[5]["highest_bid: "] < items[5]["reserve: "]and items[5]["bid_num: "] > 0:
    unmet.append(str(items[5]["item_num: "]))
  if items[6]["highest_bid: "] < items[6]["reserve: "]and items[6]["bid_num: "] > 0:
    unmet.append(str(items[6]["item_num: "]))
  if items[7]["highest_bid: "] < items[7]["reserve: "]and items[7]["bid_num: "] > 0:
    unmet.append(str(items[7]["item_num: "]))
  if items[8]["highest_bid: "] < items[8]["reserve: "]and items[8]["bid_num: "] > 0:
    unmet.append(str(items[8]["item_num: "]))
  if items[9]["highest_bid: "] < items[9]["reserve: "]and items[9]["bid_num: "] > 0:
    unmet.append(str(items[9]["item_num: "]))
  if items[10]["highest_bid: "] < items[10]["reserve: "]and items[10]["bid_num: "] > 0:
    unmet.append(str(items[10]["item_num: "]))

  print("Items that did not meet reserve: " + ', '.join(unmet) + " (" + str(len(unmet)) + " items)")

  for i in unmet:
    print("The final bid for item " + str(items[int(i)]["item_num: "]) + " was $" + str(items[int(i)]["highest_bid: "]))

def unbid():
  no_bids = []
  if items[1]["bid_num: "] == 0:
    no_bids.append(str(items[1]["item_num: "]))
  if items[2]["bid_num: "] == 0:
    no_bids.append(str(items[2]["item_num: "]))
  if items[3]["bid_num: "] == 0:
    no_bids.append(str(items[3]["item_num: "]))
  if items[4]["bid_num: "] == 0:
    no_bids.append(str(items[4]["item_num: "]))
  if items[5]["bid_num: "] == 0:
    no_bids.append(str(items[5]["item_num: "]))
  if items[6]["bid_num: "] == 0:
    no_bids.append(str(items[6]["item_num: "]))
  if items[7]["bid_num: "] == 0:
    no_bids.append(str(items[7]["item_num: "]))
  if items[8]["bid_num: "] == 0:
    no_bids.append(str(items[8]["item_num: "]))
  if items[9]["bid_num: "] == 0:
    no_bids.append(str(items[9]["item_num: "]))
  if items[10]["bid_num: "] == 0:
    no_bids.append(str(items[10]["item_num: "]))
  print("Items that were not bid on: " + ', '.join(no_bids) + " (" + str(len(no_bids)) + " items)")

total_fee() #includes sold items
reserve_unmet()
unbid()
# Out:
# item number     description     number of bids     reserve price($)
#     1             shelf                0                75.0
#     2             table                0                39.0
#     3              lamp                0                40.0
#     4         dishes(4)                0                25.0
#     5              pram                0                25.0
#     6           tea set                0                26.0
#     7           ink set                0                30.0
#     8      writing desk                0                50.0
#     9        glass case                0                150.0
#     10    stone phoenix                0                250.0
